# %% [markdown]
# # Facial Keypoint Detection
#
# Welcome back for exercise 9! As we told you, the exercises of this lecture can be subdivided into mainly two parts. The first part in which we re-invented the wheel and implemented the most important methods on our own and the second part where we start using existing libraries (that already have implemented all the methods) and start playing around with more complex network architectures.
#
# We entered stage two already before Christmas, but with the introduction of convolution neural networks this week, we are given a very powerful tool that we want to explore in this exercises. So let us start with this week's exercise, where we ask you to build a convolution neural network to perform facial keypoint detection.
#
# Before we start, let's take a look at some example images and corresponding facial keypoints:
#
# <img src='images/key_pts_example.png' width=70% height=70%/>
#
# The facial keypoints (also called facial landmarks) are the small magenta dots shown on each of the faces in the image above. These keypoints mark important areas of the face: the eyes, corners of the mouth, the nose, etc. and are relevant for a variety of computer vision tasks, such as face filters, emotion recognition, pose recognition, and more.

# %% [markdown]
# # 1. Preparation
#
# ## Imports

# %%
import os
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader
from torchvision import transforms

from exercise_code.data.facial_keypoints_dataset import FacialKeypointsDataset
from exercise_code.networks.keypoint_nn import (
    DummyKeypointModel,
    KeypointModel
)
from exercise_code.util import (
    show_all_keypoints,
    save_model,
)
from exercise_code.tests import test_keypoint_nn

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# <div class="alert alert-warning">
#     <h3>Note: Google Colab</h3>
#     <p>
# In case you don't have a GPU, you can run this notebook on Google Colab where you can access a GPU for free, but, of course, you can also run this notebook on your CPU.
#          </p>
# </div>

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ## Load and Visualize Data
# To load the data, we have already prepared a Pytorch Dataset class `FacialKeypointsDataset` for you. You can find it in `exercise_code/data/facial_keypoints_dataset.py`. Run the following cell to download the data and initialize your dataset:

# %%
download_url = 'https://vision.in.tum.de/webshare/g/i2dl/facial_keypoints.zip'
i2dl_exercises_path = os.path.dirname(os.path.abspath(os.getcwd()))
data_root = os.path.join(i2dl_exercises_path, "datasets", "facial_keypoints")
train_dataset = FacialKeypointsDataset(
    train=True,
    transform=transforms.ToTensor(),
    root=data_root,
    download_url=download_url
)
val_dataset = FacialKeypointsDataset(
    train=False,
    transform=transforms.ToTensor(),
    root=data_root,
)
print("Number of training samples:", len(train_dataset))
print("Number of validation samples:", len(val_dataset))
# Out:
# Number of training samples: 1546
# Number of validation samples: 298

# %% [markdown]
# Each sample in our dataset is a dict `{"image": image, "keypoints": keypoints}`, where
#  * `image` is a [0-1]-normalized gray-scale image of size 96x96, represented by a torch tensor of shape (CxHxW) with C=1, H=96, W=96
#     <img style="float: right;" src='images/key_pts_expl.png' width=50% height=50%/>
#  * `keypoints` is the list of K facial keypoints, stored in a torch tensor of shape (Kx2). We have K=15 keypoints that stand for:
#    * keypoints[0]: Center of the left eye
#    * keypoints[1]: Center of the right eye
#    * keypoints[2]: Left eye inner corner
#    * keypoints[3]: Left eye outer corner
#    * keypoints[4]: Right eye inner corner
#    * keypoints[5]: Right eye outer corner
#    * keypoints[6]: Left eyebrow inner end
#    * keypoints[7]: Left eyebrow outer end
#    * keypoints[8]: Right eyebrow inner end
#    * keypoints[9]: Right eyebrow outer end
#    * keypoints[10]: Nose tip
#    * keypoints[11]: Mouth left corner
#    * keypoints[12]: Mouth right corner
#    * keypoints[13]: Mouth center top lip
#    * keypoints[14]: Mouth center bottom lip
#
# Each individual facial keypoint is represented by two coordinates (x,y) that specify the horizontal and vertical location of the keypoint respectively. All keypoint values are normalized to [-1,1], such that:
#    * (x=-1,y=-1) corresponds to the top left corner,
#    * (x=-1,y=1) to the bottom left corner,
#    * (x=1,y=-1) to the top right corner,
#    * (x=1,y=1) to the bottom right corner,
#    * and (x=0,y=0) to the center of the image.
#
#
# The data downloaded is already preprocessed and hence there is no need to apply transformations in order to prepare the data. Of course, feel free to apply trainings transformation to improve your performance such as flipping the trainings images, but don't forget that these transformations (data augmentation) are only applied to your trainings set. Your validation and test set remain untouched. Also, when applying transformations such as flipping, make sure the predicted coordinates of your keypoints will change accordingly.
#
# Let's have a look at the first training sample to get a better feeling for the dataset:

# %%
image, keypoints = train_dataset[0]["image"], train_dataset[0]["keypoints"]
print("Shape of the image:", image.size())
print("Smallest value in the image:", torch.min(image))
print("Largest value in the image:", torch.max(image))
print(image)
# Out:
# Shape of the image: torch.Size([1, 96, 96])
# Smallest value in the image: tensor(0.0118)
# Largest value in the image: tensor(1.)
# tensor([[[0.3804, 0.2039, 0.2275,  ..., 0.9922, 0.9961, 0.9961],
#          [0.3333, 0.2157, 0.2588,  ..., 0.9922, 0.9961, 0.9961],
#          [0.2941, 0.2588, 0.2902,  ..., 0.9922, 0.9961, 0.9961],
#          ...,
#          [0.1294, 0.1255, 0.1255,  ..., 0.9255, 1.0000, 1.0000],
#          [0.1294, 0.1255, 0.1216,  ..., 0.9490, 0.9843, 0.9804],
#          [0.1216, 0.1176, 0.1216,  ..., 0.9255, 1.0000, 0.9922]]])

# %%
keypoints = train_dataset[0]["keypoints"]
print(keypoints)
# Out:
# tensor([[ 0.4685, -0.2319],
#         [-0.4253, -0.1953],
#         [ 0.2908, -0.2214],
#         [ 0.5992, -0.2214],
#         [-0.2685, -0.2109],
#         [-0.5873, -0.1900],
#         [ 0.1967, -0.3827],
#         [ 0.7656, -0.4295],
#         [-0.2035, -0.3758],
#         [-0.7389, -0.3573],
#         [ 0.0086,  0.2333],
#         [ 0.4163,  0.6620],
#         [-0.3521,  0.6985],
#         [ 0.0138,  0.6045],
#         [ 0.0190,  0.9076]])

# %% [markdown]
# In `exercise_code/util/vis_utils.py` we also provide you with a function `show_all_keypoints()` that takes in an image and keypoints and displays where the predicted keypoints are in the image. Let's use it to plot the first few images of our training set:

# %%
def show_keypoints(dataset, num_samples=3):
    for i in range(num_samples):
        image = dataset[i]["image"]
        key_pts = dataset[i]["keypoints"]
        show_all_keypoints(image, key_pts)
show_keypoints(train_dataset)

# %% [markdown]
# # 2. Facial Keypoint Detection
# Your task is to define and train a model for facial keypoint detection.
#
# The facial keypoint detection task can be seen as a regression problem, where the goal is to predict 30 different values that correspond to the 15 facial keypoint locations. Thus, we need to build a network that gets a (1x96x96) image as input and predicts 30 continuous outputs between [-1,1].
#
# ## Dummy Model
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>In <code>exercise_code/networks/keypoint_nn.py</code> we defined a naive <code>DummyKeypointModel</code>, which always predicts the keypoints of the first training image. Let's try it on a few images and visualize our predictions in red:
#  </p>
# </div>

# %%
def show_keypoint_predictions(model, dataset, num_samples=3):
    for i in range(num_samples):
        image = dataset[i]["image"]
        print(image.shape)
        key_pts = dataset[i]["keypoints"]
        #print(key_pts)
        predicted_keypoints = torch.squeeze(model(image).detach()).view(15,2)
        show_all_keypoints(image, key_pts, predicted_keypoints)

# %%
dummy_model = DummyKeypointModel()
show_keypoint_predictions(dummy_model, train_dataset)
# Out:
# torch.Size([1, 96, 96])
# torch.Size([1, 96, 96])
# torch.Size([1, 96, 96])

# %% [markdown]
# As we see, the model predicts the first sample perfectly, but for the remaining samples the predictions are quite off.
#
# ## Loss and Metrics
#
# To measure the quality of the model's predictions, we will use the mean squared error (https://en.wikipedia.org/wiki/Mean_squared_error), summed up over all 30 keypoint locations. In PyTorch, the mean squared error is defined in `torch.nn.MSELoss()`, and we can use it like this:

# %%
loss_fn = torch.nn.MSELoss()
for i in range(3):
    image = train_dataset[i]["image"]
    keypoints = train_dataset[i]["keypoints"]
    predicted_keypoints = torch.squeeze(dummy_model(image)).view(15,2)
    loss = loss_fn(keypoints, predicted_keypoints)
    print("Loss on image %d:" % i, loss)
# Out:
# Loss on image 0: tensor(9.3016e-10)
# Loss on image 1: tensor(0.0094)
# Loss on image 2: tensor(0.0102)

# %% [markdown]
# As expected, our dummy model achieves a loss close to 0 on the first sample, but on all other samples the loss is quite high.
#
# To obtain an evaluation score (in the notebook and on the submission server), we will use the following function:

# %%
def evaluate_model(model, dataset):
    model.eval()
    criterion = torch.nn.MSELoss()
    dataloader = DataLoader(dataset, batch_size=1, shuffle=False)
    loss = 0
    for batch in dataloader:
        image, keypoints = batch["image"], batch["keypoints"]
        predicted_keypoints = model(image).view(-1,15,2)
        loss += criterion(
            torch.squeeze(keypoints),
            torch.squeeze(predicted_keypoints)
        ).item()
    return 1.0 / (2 * (loss/len(dataloader)))

print("Score of the Dummy Model:", evaluate_model(dummy_model, val_dataset))
# Out:
# Score of the Dummy Model: 60.195747455122635

# %% [markdown]
# **To pass the assignment, you will need to achieve a score of at least 100**. As you can see, the score is calculated from the average loss, so **your average loss needs to be lower than 0.005**. Our dummy model only gets a score of around 60, so you will have to come up with a better model.

# %% [markdown]
# ## Step 1: Design your own model
#
# <div class="alert alert-info">
#     <h3>Task: Implement</h3>
#     <p> Now it is your turn to build your own model. To do so, you need to design a convolution neural network that takes images of size (Nx1x96x96) as input and produces outputs of shape (Nx30) in the range [-1,1]. Therefore, implement the <code>KeypointModel</code> class in <code>exercise_code/networks/keypoint_nn.py</code>.
#     </p>
# </div>
#
# Recall that CNN's are defined by a few types of layers:
# * Convolution layers
# * Max-pooling layers
# * Fully-connected layers
#
# You can design your network however you want, but we strongly suggest to include multiple convolution layers. You are also encouraged to use things like dropout and batch normalization to stabilize and regularize your network. If you want to build a really competitive model, have a look at some literature on keypoint detection, such as [this paper](https://arxiv.org/pdf/1710.00977.pdf).
#
# #### Define your model in the provided file
# `exercise_code/classifiers/keypoint_nn.py` file
#
# This file is mostly empty but contains the expected class name, and the methods that your model needs to implement (only `forward()` basically). You are also free to decide whether you want to use PyTorch Lightning or not.
# The only rules your model design has to follow are:
# * Inherit from either `torch.nn.Module` or `pytorch_lightning.LightningModule`
# * Perform the forward pass in forward(), predicting keypoints of shape (Nx30) for images of shape (Nx1x96x96)
# * Have less than 5 million parameters
# * Have a model size of less than 20MB after saving
#
# Furthermore, you need to pass all your hyperparameters to the model in a single dictionary:

# %%
hparams = {
    "hidden": 1
}

# %% [markdown]
# To test whether your model follows the basic rules, run the following cell:

# %%
model = KeypointModel(hparams)
test_keypoint_nn(model)
# Out:
# KeypointShapeTest passed.
# ParamCountTest passed. Your model has 0.459 mio. params.
# FileSizeTest passed. Your model is 1.8 MB large
# All tests passed for your model. Tests passed: 3/3

# %% [markdown]
# ## Step 2: Train your model
#
# <div class="alert alert-info">
#     <h3>Task: Implement</h3>
#     <p> In addition to the network itself, you will also need to write the code for the model training. You can use PyTorch Lightning for that, or you can also write it yourself in standard PyTorch.
#     </p>
# </div>
#
# **Hints:**
# * Use `torch.nn.MSELoss()` as loss function
# * Have a look at the previous notebooks for PyTorch and PyTorch Lightning in exercises 7 and 8 if you feel lost. In particular, revise `1_Cifar10_PytorchLightning.ipynb` in the optional submission from Week 7.

# %%
model = KeypointModel(hparams)
test_keypoint_nn(model)
# Out:
# KeypointShapeTest passed.
# ParamCountTest passed. Your model has 3.047 mio. params.
# FileSizeTest passed. Your model is 12.2 MB large
# All tests passed for your model. Tests passed: 3/3

# %%
import torch.optim as optim

criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
lr_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[150, 180], gamma=0.1)
batch_size = 20
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
len(train_dataloader)
# Out:
# 78

# %%
import torch.nn as nn
def initialize_weight(module):
    if isinstance(module, (nn.Conv2d)):
        nn.init.kaiming_normal_(module.weight)
    elif isinstance(module, (nn.Linear, nn.Conv2d)):
        nn.init.kaiming_normal_(module.weight)   
    elif isinstance(module, nn.BatchNorm2d):
        nn.init.constant_(module.weight, 1)
        nn.init.constant_(module.bias, 0)
        
model.apply(initialize_weight)
# Out:
# KeypointModel(
#   (cnn): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#     (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#     (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#     (11): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1))
#     (12): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU()
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=2304, out_features=1000, bias=True)
#     (1): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=1000, out_features=500, bias=True)
#     (4): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Linear(in_features=500, out_features=128, bias=True)
#     (7): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): Linear(in_features=128, out_features=30, bias=True)
#     (10): BatchNorm1d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): Tanh()
#   )
# )

# %%
def run_epoch(model, optimizer, dataloader, train):
    
    if train:
        model.train()
    else:
        model.eval()
    
    
    running_loss = 0.0
    #epoch_score = 0.0
   
    for data in dataloader:
        image, keypoints = data["image"], data["keypoints"]
        image.to(device)
        keypoints.to(device)
       
        # forward
        
        if train:
            optimizer.zero_grad()
        
        with torch.set_grad_enabled(True):
            predicted_keypoints = model(image).view(-1,15,2)
            loss = criterion(
                   torch.squeeze(keypoints),
                   torch.squeeze(predicted_keypoints))
           
            if train:
            # backward
                loss.backward()
                optimizer.step()
           
        # statistics
        running_loss += loss.item()
   
    running_loss = running_loss / (len(dataloader) * batch_size)
    return running_loss

# %%
import copy
train_loss_history = []
val_loss_history = []

def fit(model, optimizer,lr_scheduler, train_dataloader, val_dataloader, max_epochs, patience): #lr_scheduler, patience
    

    best_loss = 10
    
    for epoch in range(max_epochs):
        train_loss = run_epoch(model, optimizer, train_dataloader, train=True)
        lr_scheduler.step()
        val_loss = run_epoch(model, None, val_dataloader, train=False)
        #print("Epoch: ", epoch, "train loss: %.2e", train_loss, "val loss: %.2e", val_loss)
        train_loss_history.append(train_loss)
        val_loss_history.append(val_loss)
        
        print("[Epoch %d, train loss: %.2e, val loss: %.2e" % (epoch+1, train_loss, val_loss))
        if val_loss <= best_loss:
            best_epoch = epoch
            best_loss = val_loss
            best_model_weights = copy.deepcopy(model.state_dict())
                
        # Early stopping
        if epoch - best_epoch >= patience:
            break
            
    model.load_state_dict(best_model_weights)

# %%
fit(model, optimizer,lr_scheduler, train_dataloader, val_dataloader, max_epochs=200, patience=25)
#lr_scheduler
# Out:
# [Epoch 1, train loss: 1.40e-02, val loss: 1.41e-02
# [Epoch 2, train loss: 9.08e-03, val loss: 9.61e-03
# [Epoch 3, train loss: 8.15e-03, val loss: 7.57e-03
# [Epoch 4, train loss: 7.83e-03, val loss: 5.89e-03
# [Epoch 5, train loss: 7.56e-03, val loss: 7.95e-03
# [Epoch 6, train loss: 6.32e-03, val loss: 9.30e-03
# [Epoch 7, train loss: 6.47e-03, val loss: 7.75e-03
# [Epoch 8, train loss: 6.11e-03, val loss: 7.74e-03
# [Epoch 9, train loss: 5.66e-03, val loss: 7.53e-03
# [Epoch 10, train loss: 6.09e-03, val loss: 2.39e-03
# [Epoch 11, train loss: 6.07e-03, val loss: 1.24e-03
# [Epoch 12, train loss: 5.56e-03, val loss: 5.74e-03
# [Epoch 13, train loss: 6.11e-03, val loss: 7.52e-03
# [Epoch 14, train loss: 5.23e-03, val loss: 7.56e-03
# [Epoch 15, train loss: 4.48e-03, val loss: 5.81e-03
# [Epoch 16, train loss: 3.46e-03, val loss: 4.62e-03
# [Epoch 17, train loss: 2.66e-03, val loss: 3.17e-03
# [Epoch 18, train loss: 1.85e-03, val loss: 2.52e-03
# [Epoch 19, train loss: 1.60e-03, val loss: 2.06e-03
# [Epoch 20, train loss: 1.37e-03, val loss: 1.73e-03
# [Epoch 21, train loss: 1.27e-03, val loss: 1.90e-03
# [Epoch 22, train loss: 9.92e-04, val loss: 1.51e-03
# [Epoch 23, train loss: 8.23e-04, val loss: 1.13e-03
# [Epoch 24, train loss: 5.28e-04, val loss: 3.84e-04
# [Epoch 25, train loss: 3.87e-04, val loss: 3.79e-04
# [Epoch 26, train loss: 3.59e-04, val loss: 3.43e-04
# [Epoch 27, train loss: 3.48e-04, val loss: 3.32e-04
# [Epoch 28, train loss: 3.25e-04, val loss: 3.28e-04
# [Epoch 29, train loss: 3.20e-04, val loss: 3.34e-04
# [Epoch 30, train loss: 3.08e-04, val loss: 2.91e-04
# [Epoch 31, train loss: 2.97e-04, val loss: 2.54e-04
# [Epoch 32, train loss: 2.90e-04, val loss: 2.58e-04
# [Epoch 33, train loss: 2.85e-04, val loss: 2.53e-04
# [Epoch 34, train loss: 2.84e-04, val loss: 2.96e-04
# [Epoch 35, train loss: 2.77e-04, val loss: 2.57e-04
# [Epoch 36, train loss: 2.79e-04, val loss: 2.47e-04
# [Epoch 37, train loss: 2.75e-04, val loss: 2.57e-04
# [Epoch 38, train loss: 2.77e-04, val loss: 2.43e-04
# [Epoch 39, train loss: 2.69e-04, val loss: 2.61e-04
# [Epoch 40, train loss: 2.69e-04, val loss: 2.59e-04
# [Epoch 41, train loss: 2.64e-04, val loss: 2.29e-04
# [Epoch 42, train loss: 2.62e-04, val loss: 2.44e-04
# [Epoch 43, train loss: 2.61e-04, val loss: 2.25e-04
# [Epoch 44, train loss: 2.65e-04, val loss: 2.29e-04
# [Epoch 45, train loss: 2.62e-04, val loss: 2.44e-04
# [Epoch 46, train loss: 2.60e-04, val loss: 2.41e-04
# [Epoch 47, train loss: 2.56e-04, val loss: 2.13e-04
# [Epoch 48, train loss: 2.56e-04, val loss: 2.56e-04
# [Epoch 49, train loss: 2.51e-04, val loss: 2.26e-04
# [Epoch 50, train loss: 2.52e-04, val loss: 2.28e-04
# [Epoch 51, train loss: 2.51e-04, val loss: 2.18e-04
# [Epoch 52, train loss: 2.46e-04, val loss: 2.18e-04
# [Epoch 53, train loss: 2.44e-04, val loss: 2.45e-04
# [Epoch 54, train loss: 2.41e-04, val loss: 1.90e-04
# [Epoch 55, train loss: 2.44e-04, val loss: 2.59e-04
# [Epoch 56, train loss: 2.39e-04, val loss: 2.06e-04
# [Epoch 57, train loss: 2.36e-04, val loss: 2.15e-04
# [Epoch 58, train loss: 2.30e-04, val loss: 1.81e-04
# [Epoch 59, train loss: 2.25e-04, val loss: 2.17e-04
# [Epoch 60, train loss: 2.20e-04, val loss: 1.91e-04
# [Epoch 61, train loss: 2.13e-04, val loss: 2.12e-04
# [Epoch 62, train loss: 2.05e-04, val loss: 1.72e-04
# [Epoch 63, train loss: 1.96e-04, val loss: 1.76e-04
# [Epoch 64, train loss: 1.83e-04, val loss: 1.95e-04
# [Epoch 65, train loss: 1.70e-04, val loss: 1.53e-04
# [Epoch 66, train loss: 1.64e-04, val loss: 2.33e-04
# [Epoch 67, train loss: 1.52e-04, val loss: 1.70e-04
# [Epoch 68, train loss: 1.47e-04, val loss: 1.29e-04
# [Epoch 69, train loss: 1.37e-04, val loss: 1.13e-04
# [Epoch 70, train loss: 1.29e-04, val loss: 1.28e-04
# [Epoch 71, train loss: 1.17e-04, val loss: 1.06e-04
# [Epoch 72, train loss: 1.12e-04, val loss: 9.86e-05
# [Epoch 73, train loss: 1.10e-04, val loss: 1.43e-04
# [Epoch 74, train loss: 1.02e-04, val loss: 8.02e-05
# [Epoch 75, train loss: 9.90e-05, val loss: 9.68e-05
# [Epoch 76, train loss: 9.16e-05, val loss: 9.12e-05
# [Epoch 77, train loss: 9.04e-05, val loss: 6.90e-05
# [Epoch 78, train loss: 8.40e-05, val loss: 5.92e-05
# [Epoch 79, train loss: 8.31e-05, val loss: 6.85e-05
# [Epoch 80, train loss: 8.03e-05, val loss: 5.15e-05
# [Epoch 81, train loss: 7.84e-05, val loss: 5.00e-05
# [Epoch 82, train loss: 7.47e-05, val loss: 6.57e-05
# [Epoch 83, train loss: 7.19e-05, val loss: 5.08e-05
# [Epoch 84, train loss: 7.04e-05, val loss: 5.95e-05
# [Epoch 85, train loss: 6.87e-05, val loss: 4.82e-05
# [Epoch 86, train loss: 6.79e-05, val loss: 5.94e-05
# [Epoch 87, train loss: 6.82e-05, val loss: 4.84e-05
# [Epoch 88, train loss: 6.40e-05, val loss: 5.18e-05
# [Epoch 89, train loss: 6.17e-05, val loss: 4.91e-05
# [Epoch 90, train loss: 6.03e-05, val loss: 3.93e-05
# [Epoch 91, train loss: 5.83e-05, val loss: 4.09e-05
# [Epoch 92, train loss: 5.81e-05, val loss: 4.57e-05
# [Epoch 93, train loss: 5.75e-05, val loss: 3.64e-05
# [Epoch 94, train loss: 5.72e-05, val loss: 4.01e-05
# [Epoch 95, train loss: 5.59e-05, val loss: 3.92e-05
# [Epoch 96, train loss: 5.45e-05, val loss: 3.81e-05
# [Epoch 97, train loss: 5.55e-05, val loss: 5.08e-05
# [Epoch 98, train loss: 5.34e-05, val loss: 3.84e-05
# [Epoch 99, train loss: 5.36e-05, val loss: 3.24e-05
# [Epoch 100, train loss: 5.26e-05, val loss: 4.19e-05
# [Epoch 101, train loss: 5.21e-05, val loss: 3.55e-05
# [Epoch 102, train loss: 5.18e-05, val loss: 3.71e-05
# [Epoch 103, train loss: 5.01e-05, val loss: 3.32e-05
# [Epoch 104, train loss: 4.93e-05, val loss: 3.84e-05
# [Epoch 105, train loss: 4.86e-05, val loss: 3.68e-05
# [Epoch 106, train loss: 4.81e-05, val loss: 3.06e-05
# [Epoch 107, train loss: 4.73e-05, val loss: 2.98e-05
# [Epoch 108, train loss: 4.61e-05, val loss: 3.33e-05
# [Epoch 109, train loss: 4.74e-05, val loss: 3.44e-05
# [Epoch 110, train loss: 4.48e-05, val loss: 3.46e-05
# [Epoch 111, train loss: 4.52e-05, val loss: 3.42e-05
# [Epoch 112, train loss: 4.39e-05, val loss: 2.68e-05
# [Epoch 113, train loss: 4.63e-05, val loss: 2.82e-05
# [Epoch 114, train loss: 4.42e-05, val loss: 2.89e-05
# [Epoch 115, train loss: 4.36e-05, val loss: 3.25e-05
# [Epoch 116, train loss: 4.24e-05, val loss: 3.15e-05
# [Epoch 117, train loss: 4.06e-05, val loss: 3.61e-05
# [Epoch 118, train loss: 4.31e-05, val loss: 3.08e-05
# [Epoch 119, train loss: 4.12e-05, val loss: 2.66e-05
# [Epoch 120, train loss: 4.19e-05, val loss: 2.74e-05
# [Epoch 121, train loss: 4.18e-05, val loss: 2.80e-05
# [Epoch 122, train loss: 3.95e-05, val loss: 3.10e-05
# [Epoch 123, train loss: 4.08e-05, val loss: 2.74e-05
# [Epoch 124, train loss: 4.14e-05, val loss: 2.71e-05
# [Epoch 125, train loss: 4.08e-05, val loss: 2.71e-05
# [Epoch 126, train loss: 4.06e-05, val loss: 2.92e-05
# [Epoch 127, train loss: 4.07e-05, val loss: 2.76e-05
# [Epoch 128, train loss: 3.83e-05, val loss: 2.81e-05
# [Epoch 129, train loss: 3.83e-05, val loss: 2.61e-05
# [Epoch 130, train loss: 3.80e-05, val loss: 2.58e-05
# [Epoch 131, train loss: 3.79e-05, val loss: 2.67e-05
# [Epoch 132, train loss: 3.79e-05, val loss: 2.55e-05
# [Epoch 133, train loss: 3.79e-05, val loss: 3.11e-05
# [Epoch 134, train loss: 3.94e-05, val loss: 2.68e-05
# [Epoch 135, train loss: 3.71e-05, val loss: 2.95e-05
# [Epoch 136, train loss: 3.69e-05, val loss: 2.62e-05
# [Epoch 137, train loss: 3.65e-05, val loss: 2.29e-05
# [Epoch 138, train loss: 3.56e-05, val loss: 2.42e-05
# [Epoch 139, train loss: 3.96e-05, val loss: 2.74e-05
# [Epoch 140, train loss: 3.78e-05, val loss: 2.63e-05
# [Epoch 141, train loss: 3.77e-05, val loss: 2.40e-05
# [Epoch 142, train loss: 3.66e-05, val loss: 2.40e-05
# [Epoch 143, train loss: 3.72e-05, val loss: 2.48e-05
# [Epoch 144, train loss: 3.40e-05, val loss: 2.57e-05
# [Epoch 145, train loss: 3.53e-05, val loss: 2.56e-05
# [Epoch 146, train loss: 3.68e-05, val loss: 2.69e-05
# [Epoch 147, train loss: 3.68e-05, val loss: 2.71e-05
# [Epoch 148, train loss: 3.76e-05, val loss: 2.42e-05
# [Epoch 149, train loss: 3.71e-05, val loss: 2.59e-05
# [Epoch 150, train loss: 3.58e-05, val loss: 2.52e-05
# [Epoch 151, train loss: 3.36e-05, val loss: 2.15e-05
# [Epoch 152, train loss: 3.22e-05, val loss: 2.19e-05
# [Epoch 153, train loss: 3.30e-05, val loss: 2.16e-05
# [Epoch 154, train loss: 3.09e-05, val loss: 2.06e-05
# [Epoch 155, train loss: 3.05e-05, val loss: 2.00e-05
# [Epoch 156, train loss: 3.15e-05, val loss: 2.17e-05
# [Epoch 157, train loss: 3.19e-05, val loss: 2.18e-05
# [Epoch 158, train loss: 2.99e-05, val loss: 2.26e-05
# [Epoch 159, train loss: 2.98e-05, val loss: 2.21e-05
# [Epoch 160, train loss: 2.94e-05, val loss: 2.32e-05
# [Epoch 161, train loss: 3.05e-05, val loss: 2.28e-05
# [Epoch 162, train loss: 2.93e-05, val loss: 2.16e-05
# [Epoch 163, train loss: 3.14e-05, val loss: 2.10e-05
# [Epoch 164, train loss: 2.92e-05, val loss: 1.96e-05
# [Epoch 165, train loss: 3.19e-05, val loss: 2.12e-05
# [Epoch 166, train loss: 2.86e-05, val loss: 2.04e-05
# [Epoch 167, train loss: 2.91e-05, val loss: 2.08e-05
# [Epoch 168, train loss: 2.97e-05, val loss: 2.21e-05
# [Epoch 169, train loss: 3.27e-05, val loss: 2.18e-05
# [Epoch 170, train loss: 3.13e-05, val loss: 2.01e-05
# [Epoch 171, train loss: 2.93e-05, val loss: 2.06e-05
# [Epoch 172, train loss: 2.96e-05, val loss: 2.18e-05
# [Epoch 173, train loss: 2.92e-05, val loss: 2.21e-05
# [Epoch 174, train loss: 2.96e-05, val loss: 2.07e-05
# [Epoch 175, train loss: 2.96e-05, val loss: 2.13e-05
# [Epoch 176, train loss: 2.83e-05, val loss: 2.12e-05
# [Epoch 177, train loss: 3.22e-05, val loss: 2.16e-05
# [Epoch 178, train loss: 2.99e-05, val loss: 2.21e-05
# [Epoch 179, train loss: 2.92e-05, val loss: 2.38e-05
# [Epoch 180, train loss: 2.96e-05, val loss: 2.33e-05
# [Epoch 181, train loss: 3.02e-05, val loss: 2.21e-05
# [Epoch 182, train loss: 2.75e-05, val loss: 2.15e-05
# [Epoch 183, train loss: 2.84e-05, val loss: 2.31e-05
# [Epoch 184, train loss: 2.98e-05, val loss: 2.12e-05
# [Epoch 185, train loss: 2.84e-05, val loss: 2.07e-05
# [Epoch 186, train loss: 2.90e-05, val loss: 2.16e-05
# [Epoch 187, train loss: 2.86e-05, val loss: 2.27e-05
# [Epoch 188, train loss: 2.92e-05, val loss: 2.04e-05
# [Epoch 189, train loss: 2.94e-05, val loss: 2.28e-05

# %%
import matplotlib.pyplot as plt
plt.plot(train_loss_history)
plt.plot(val_loss_history)
plt.title("Loss")
plt.xlabel('iteration')
plt.ylabel('loss')
plt.legend(['loss'])
plt.show()

# %% [markdown]
# When you're done training, run the cells below to visualize some predictions of your model, and to compute a validation score:

# %%
def show_keypoint_predictions2(model, dataset, num_samples=3):
    for i in range(num_samples):
        image = dataset[i]["image"]
        image = image.view(1,1,96,96)
        #print(image.shape)
        key_pts = dataset[i]["keypoints"]
        #print(key_pts)
        predicted_keypoints = torch.squeeze(model(image).detach()).view(15,2)
        show_all_keypoints(image, key_pts, predicted_keypoints)

# %%
show_keypoint_predictions2(model, val_dataset)

# %%
print("Score:", evaluate_model(model, val_dataset))
# Out:
# Score: 1276.6912452012677

# %% [markdown]
# # 3. Save Your Model for Submission
#
# If your model achieved a validation score of 100 or higher, save your model with the cell below and submit it to [the submission server](https://dvl.in.tum.de/teaching/submission/). Your validation set is of course different from the test set on our server, so results may vary. Nevertheless, you will have a reasonable close approximation about your performance.
#
# Before that, we will check again whether the number of parameters is below 5 Mio. and the file size is below 20 MB.

# %%
save_model(model, "facial_keypoints.p")
# Out:
# 'models\\facial_keypoints.p'

# %% [markdown]
# Congrats - you've now finished your first Convolution Neural Network! Simply run the following cell to create a zipped file for your implementations.

# %%
# Now zip the folder for upload
from exercise_code.util.submit import submit_exercise

submit_exercise('exercise09')
# Out:
# relevant folders: ['exercise_code', 'models']
# notebooks files: ['1_facial_keypoints-Copy1.ipynb', '1_facial_keypoints-Copy2.ipynb', '1_facial_keypoints.ipynb', 'Optional-spatial_batchnorm.ipynb']
# Adding folder exercise_code
# Adding folder models
# Adding notebook 1_facial_keypoints-Copy1.ipynb
# Adding notebook 1_facial_keypoints-Copy2.ipynb
# Adding notebook 1_facial_keypoints.ipynb
# Adding notebook Optional-spatial_batchnorm.ipynb
# Zipping successful! Zip is stored under: C:\Users\asus\Desktop\exercise_09\exercise09.zip

# %% [markdown]
# # Submission Goals
#
# - Goal: Implement and train a convolution neural network for facial keypoint detection.
# - Passing Criteria: Reach **Score >= 100** on __our__ test dataset. The submission system will show you your score after you submit.
#
# - Submission start: __Thursday, January 21, 2021 - 13:00__
# - Submission deadline: __Wednesday, January 27, 2021 - 15:59__
# - You can make **$\infty$** submissions until the deadline. Your __best submission__ will be considered for bonus
